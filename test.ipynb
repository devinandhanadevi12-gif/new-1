# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_absolute_error, r2_score

# %%
#load the dataset
df = pd.read_csv('mark_hour.csv')
print("Data loaded successfully. Here are the first 5 rows:")
print(df.head())
# Out:
# Data loaded successfully. Here are the first 5 rows:
#    hours  marks
# 0    2.5     21
# 1    5.1     47
# 2    4.3     50
# 3    2.4     20
# 4    5.7     70

# %%
#prepare the data 
x = df.iloc[:, :-1].values  # Hours (Attributes)
y = df.iloc[:, 1].values #scores(Labels)

#split into training and Test set (80/20 split)
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=42)
print("Data split into training and testing sets.")
# Out:
# Data split into training and testing sets.

# %%
#Initialize and train the Linear regression Model 
regressor = LinearRegression()
regressor.fit(x_train, y_train)
print("Training complete")
# Out:
# Training complete

# %%
# predict the scores 
y_pred = regressor.predict(x_test)

# Calculate Evaluation Metrics
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"mean_absolute_error:{mae:.2f}")
print(f"R-squared Score: {r2:.2f}")
# Out:
# mean_absolute_error:2.50
# R-squared Score: 0.77

# %%
# plotting the regression line 
line = regressor.coef_* x + regressor.intercept_
plt.figure(figsize=(10,6))
plt.scatter(x,y, color='royalblue',edgecolors='black', s=100, label='Data Points')
plt.plot(x, line,color='crimson', linewidth=2, label='Regression Line')
plt.title('Linear Regression: hours vs marks', fontsize=15)
plt.xlabel('Hours studied', fontsize=12)
plt.ylabel('Percentage score', fontsize=15)
plt.legend()
plt.show()

# %%
# predict for a specific value(eg.9.25 hours)
hours = float(input("enter hours"))
prediction = regressor.predict([[hours]])
print(f"Predicted score for {hours} hours of study: {prediction[0]:.2f}")
# Out:
# Predicted score for 5.0 hours of study: 49.24
